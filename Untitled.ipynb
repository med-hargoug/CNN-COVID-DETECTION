# %%
pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\user\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in c:\users\user\anaconda3\lib\site-packages (from kagglehub) (0.1.18)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from kagglehub) (23.2)
# Requirement already satisfied: pyyaml in c:\users\user\anaconda3\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from kagglehub) (2.32.2)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from kagglehub) (4.66.4)
# Requirement already satisfied: protobuf in c:\users\user\anaconda3\lib\site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (3.20.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->kagglehub) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("manishkc06/covid19-detection")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\User\.cache\kagglehub\datasets\manishkc06\covid19-detection\versions\1

# %%
import numpy as np
import pandas as pd
import shutil 

dst = r"C:\Users\User\Documents\AI_projet\data"

shutil.copytree(path , dst , dirs_exist_ok=True)
# Out:
# 'C:\\Users\\User\\Documents\\AI_projet\\data'

# %%
df = pd.read_csv(r"C:\Users\User\Documents\AI_projet\data\Training_set_covid.csv")
df.head()
# Out:
#       filename  label
# 0  Image_1.jpg      1
# 1  Image_2.jpg      0
# 2  Image_3.jpg      0
# 3  Image_4.jpg      0
# 4  Image_5.jpg      0

# %%
df.isnull().sum()
# Out:
# filename    0
# label       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  3479 non-null   object
#  1   label     3479 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 54.5+ KB

# %%
print(df['label'].value_counts())
# Out:
# label
# 0    3073
# 1     406
# Name: count, dtype: int64
